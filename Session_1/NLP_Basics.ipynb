# %% [markdown]
# ### 3.
# Given the sentence 'I love ordering pizza from Zomato!', break it down into individual words (tokens) using Python's split() function, and print the list of tokens.<br><br><em><strong>Hint:</strong> Use sentence.split() to get the words.</em>

# %%
sentence = 'I love ordering pizza from Zomato!'
tokens = sentence.split()
print(tokens)
# Out:
# ['I', 'love', 'ordering', 'pizza', 'from', 'Zomato!']

# %% [markdown]
# def is_spam(email_text):
#     text = email_text.lower()
#     if 'win' in text or 'free' in text:
#         return True
#     else:
#         return False
#
# print(is_spam('You win a free gift!'))
# print(is_spam('Hey, are we still meeting tomorrow?'))

# %%
review = input('Enter a movie review: ')
if 'good' in review.lower():
    print('Positive')
elif 'bad' in review.lower():
    print('Negative')
else:
    print('Neutral')
# Out:
# Positive

# %% [markdown]
# ### 5.
# Imagine you are designing a spam filter for an email app. Write a Python function is_spam(email_text) that returns True if the email_text contains the word 'win' or 'free', otherwise returns False. Test your function with two examples.

# %%
def is_spam(email_text):
    text = email_text.lower()
    if 'win' in text or 'free' in text:
        return True
    else:
        return False

print(is_spam('You win a free gift!'))
print(is_spam('Hey, are we still meeting tomorrow?'))
# Out:
# True
# False
